# %%
dict = {"A" : "100", "Б" : "101", "В" : "00", "Г" : "01"}
print(dict)
# Д Е
k = 1
while (k<5):
    if k == 1:
        for i in range(2):
            print(i)
    if k == 2:
        for i in range(2):
            for j in range(2):
                if i == 0 and j == 0:
                    continue
                elif i == 0 and j == 1:
                    continue
                else:
                    print(i,j)
    if k == 3:
        for i in range(2):
            for j in range(2):
                if i == 0 and j == 0:
                    continue
                elif i == 0 and j == 1:
                    continue
                for z in range(2):
                    if i == 1 and j == 0 and z == 0:
                        continue
                    elif i == 1 and j == 0 and z == 1:
                        continue
                    else:
                        print(i,j,z)
    if k == 4:
        for i in range(2):
            for j in range(2):
                if i == 0 and j == 0:
                    continue
                elif i == 0 and j == 1:
                    continue
                for z in range(2):
                    if i == 1 and j == 0 and z == 0:
                        continue
                    elif i == 1 and j == 0 and z == 1:
                        continue
                    else:
                        for w in range(2):
                            print(i,j,z,w)
    k += 1
