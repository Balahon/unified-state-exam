# %%
for N in range(40): #ГЕНЕРАЦИЯ
    New = ""   
    Nbin = bin(N)[2::]  #ПЕРЕВОДИМ ЧИСЛО N из 10 в 2 (без учета первых 2 символов)
    if Nbin.count("1") % 2 == 0:  #проверяем количество едениц в полученной строке
        New += "10" + Nbin[2::] + "0" 
    else:
        New += "11" + Nbin[2::] + "1"
    END = int(New,2) #переводим из 2 в 10 сс
    if END > 40:
        break
print(N)
# Out:
# 16

# %%
for N in range(999,1020):
    a = bin(N)[2::]
    b = ""
    for i in a:
        if i == "0":
            b = b+"1"
        else:
            b=b+"0"
    if (int(a,2)-int(b,2)) == 999:
        print(N)
        break
# Out:
# 1011

# %%
# На вход алгоритма подаётся натуральное число N. Алгоритм строит по нему новое число R следующим образом.
# 1. Строится двоичная запись числа N.
# 2. Далее эта запись обрабатывается по следующему правилу:
# а) если число N делится на 3, то к этой записи дописываются три последние двоичные цифры;
# б) если число N на 3 не делится, то остаток от деления умножается на 3, переводится в двоичную запись и дописывается в конец
# числа.
# Полученная таким образом запись является двоичной записью искомого числа R.
# 3. Результат переводится в десятичную систему и выводится на экран.
# Например, для исходного числа 12 = 11002 результатом является число 11001002 = 100, а для исходного числа 4 = 1002
# результатом является число 100112 = 19.
# Укажите максимальное число N, после обработки которого с помощью этого алгоритма получается число R, меньшее чем 76.
for a in range(4,100): # начинаем цикл от 4
    if a % 3 == 0: # если число кратно 3
        r = bin(a)[2::] + bin(a)[-3::] #к двоичной записи дописываются три последние двоичные цифры;
        print(a, " ", int(r,2))
    else:
        c = a%3*3 # если число N на 3 не делится, то остаток от деления умножается на 3
        r = bin(a)[2::] + bin(c)[2::] #  переводится в двоичную запись и дописывается в конец числа.
        print(a, " ", int(r,2))
# в полученном списке ищем последнее число, что не больше 76
# ответ 16
# Out:
# 4   19
# 5   46
# 6   54
# 7   31
# 8   70
# 9   73
# 10   43
# 11   94
# 12   100
# 13   55
# 14   118
# 15   127
# 16   67
# 17   142
# 18   146
# 19   79
# 20   166
# 21   173
# 22   91
# 23   190
# 24   192
# 25   103
# 26   214
# 27   219
# 28   115
# 29   238
# 30   246
# 31   127
# 32   262
# 33   265
# 34   139
# 35   286
# 36   292
# 37   151
# 38   310
# 39   319
# 40   163
# 41   334
# 42   338
# 43   175
# 44   358
# 45   365
# 46   187
# 47   382
# 48   384
# 49   199
# 50   406
# 51   411
# 52   211
# 53   430
# 54   438
# 55   223
# 56   454
# 57   457
# 58   235
# 59   478
# 60   484
# 61   247
# 62   502
# 63   511
# 64   259
# 65   526
# 66   530
# 67   271
# 68   550
# 69   557
# 70   283
# 71   574
# 72   576
# 73   295
# 74   598
# 75   603
# 76   307
# 77   622
# 78   630
# 79   319
# 80   646
# 81   649
# 82   331
# 83   670
# 84   676
# 85   343
# 86   694
# 87   703
# 88   355
# 89   718
# 90   722
# 91   367
# 92   742
# 93   749
# 94   379
# 95   766
# ...

# %%
for N in range(1000):
    Q = N
    for q in range(3):
        B_N = bin(N)[2:] # перевод из 10->2
        N = str(N) # из числа в строку
        x = [int(i) for i in N] # разбиваем строку на отдельные числа
        if sum(x) % 2 == 0: # проверяем сумму чисел
            B_N = B_N + '0' # B_N += '0'
        else:B_N = B_N +'1' # B_N += '1'
        N = int(B_N,2) # из 2 -> 10
    if N > 2054:
        print(Q)
# Out:
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# ...

# %%
for N in range(100):
    b = bin(N)[2:]
    c = b.count('1') % 2
    b = b + str(c)
    c = b.count('1') % 2
    b = b + str(c)
    if int(b,2) > 170:
        print(N)
        break

# %%
for N in range(100,1000):
    s1 = N//100 + N//10%10
    s2 = N//10%10 + N%10
    if s1 > s2 and s1 == 17 and s2 == 15:
        print(s1,s2)
    elif s2>s1 and s2 == 17 and s1 == 15:
        print(s1,s2)

# %%
for N in range(100,1000):
    s1 = N//100 + N//10%10
    s2 = N//10%10 + N%10
    if s1 > s2 and s1 == 17 and s2 == 15:
        print(s1,s2)
    elif s2>s1 and s2 == 17 and s1 == 15:
        print(s1,s2)

# %%
count = 0
for i in range(1000,10000):
    a = str(i)
    if int(a[0]) % 2 != 0 and int(a[1]) % 2 != 0 and int(a[2]) % 2 != 0 and int(a[3]) % 2 != 0:
        summa1 = int(a[0]) + int(a[1])
        summa2 = int(a[2]) + int(a[3])
        mas = (sorted([summa2, summa1]))
        if mas[0] == 4 and mas[1] == 14:
            count += 1
            print(a)
print(count)

# %%
for N in range(100):
    a = bin(N)[2::]
    count1 = a.count("1")
    if count1 % 2 == 0:
        a += "0"
    else:
        a += "1"
    count2 = a.count("1")
    if count2 % 2 == 0:
        a += "0"
    else:
        a += "1"
    R = (int(a,2))
    if R > 43:
        print(N)
print(R)

# %%
for i in range(1000,10000):
    j = str(i) # число 9810 переходит в строковую переменную
    str1 = int(j[0]) + int(j[1]) # находим сумму первой пары чисел
    str2 = int(j[2]) + int(j[3]) # # находим сумму второй пары чисел
    a = str(min(str1,str2)) + str(max(str1,str2))
    if a == "117":
        print(i)

# %%
for N in range(256):
    a = bin(N)[2::]
    binarZapis = "0"*(8-len(a)) + a
    # print(binarZapis)
    binarZapis2 = ""
    for x in range(8):
        if binarZapis[x] == "0":
            binarZapis2 += "1"
        else:
            binarZapis2 += "0"
    # print(binarZapis2)
    des = int(binarZapis2,2)
    if (des - N) == 111:
        print(N)

# %%
# 1 Строим 2 запись N
for N in range(1000000):
    N_bin = bin(N)[2:]
    c = 0 # порядковый номер
    edin = 0 # количество единиц
    nuli = 0 # количество нулей
    for i in N_bin:
        c += 1
        if c%2 == 0: # порядковый номер четный?
            if i == '1': # стоит 1?
                edin += 1
        else: # порядковые номера нечетные
            if i == '0': # стоит 0?
                nuli += 1
    R = (abs(edin-nuli)) # модуль разницы
    if R == 5: # модуль разницы = 5?
        print(N) # печатаем исходное число
        break # прерываем цикл

# %%
for N in range(1000):
    N_bin = bin(N)[2:]
    ed = N_bin.count('1') # считаем количество 1
    ost = ed%2 # получаем остаток от деления на 2
    N_bin = N_bin + str(ost) # дописываем остатток в конец
    ed = N_bin.count('1')  # считаем количество 1
    ost = ed % 2  # получаем остаток от деления на 2
    N_bin = N_bin + str(ost) # дописываем остатток в конец
    R = int(N_bin,2) # переводим из 2 в 10 сс
    if R > 43:
        print(N)
        break

# %%
for N1 in range(100):
    N = N1 - N1%4
    N_b = bin(N)[2:]
    N_b = N_b + str(N_b.count('1')%2)
    N_b = N_b + str(N_b.count('1') % 2)
    if int(N_b,2) > 100:
        print(int(N_b,2))
        break

# %%
# четырехричная система счисления
for N in range(1,100):
    N_chet = ''
    N1 = N
    while(N1!=0):
        N_chet += str(N1%4)
        N1 = N1//4
    N_chet = N_chet[-1::-1]
    if N % 4 == 0:
        N_chet += N_chet[-2::]
    else:
        q = N%4*2
        if q == 2:
            N_chet += '2'
        else:
            N_chet += str(q//4) + str(q%4)
    R = int(N_chet,4)
    if R <  261:
        print(N)

# %%
# На вход алгоритма подаётся натуральное число N. Алгоритм строит по нему новое число R следующим образом.
# Строится троичная запись числа N
# Далее эта запись обрабатывается по следующему правилу:
# a) если число N делится на 3, то к этой записи дописываются две последние троичные цифры;
# б) если число N на 3 не делится, то остаток от деления умножается на 5, переводится в троичную запись и дописывается в конец числа.
# Полученная таким образом запись является троичной записью искомого числа R.
# Результат переводится в десятичную систему и выводится на экран.
# Укажите минимальное число R, большее 150, которое может быть получено с помощью описанного алгоритма. В ответе запишите это число в десятичной системе счисления.
q = [] # список для удобного нахожд мин
for N in range(1,100):
    N1 = N # Клон N
    N_3 = ''
    while N1 > 0: # перевод в 3сс
        N_3 = str(N1%3)+N_3 # сохраняем остатки деления на 3
        N1 = N1 // 3 # понижаем число в 3 раза
    if N % 3 == 0: # проверяем делимость исходного числа на 3
        N_3 = N_3 + N_3[-2::] # дописываем в конец последние 2 числа
    else:
        N_OST = N % 3 * 5 # находим остаток и умноджаем на 5
        N_OST_3 = '' # сюда записывается остатки деления на 3
        while N_OST > 0: # перевеодим остаток в 3 сс
            N_OST_3 = str(N_OST % 3) + N_OST_3 # записываем остатки деления
            N_OST = N_OST // 3 # уменьшаем число в 3 раза
        N_3 = N_3 + N_OST_3 # дописываем в конец полученное число
    R = int(N_3,3) # переводим из 3 в 10
    if R > 150:
        q.append(R) # добавляем в список полученный ответ
print(min(q)) # нашли минимальное значение из списка

# %%
q = []
for N in range(2,100):
    x = N
    N1 = ''
    sist = 3 
    while(x>0):  # перевод в любую сист сч
        N1 = str(x % sist)+N1
        x = x // sist
    if N%3 == 0:
        N1 += N1[-2:]
    else:
        ost = (N % 3)*5
        ost1 = ''
        while (ost > 0):
            ost1 = str(ost % sist) + ost1
            ost = ost // sist
        N1 = N1+ost1
    R = int(N1,3)
    if R >= 290:
        q.append(N)
print(min(q))

# %%
for N in range(1,1000000):
    N_7 = ''
    x = N
    while(N > 0):
        N_7 += str(N%7)
        N = N//7
    N_7 = N_7[-1::-1]
    if N_7.count('2')%2==0:
        N_7 += '555'
    else:
        N_7 = '1'+N_7
    R = int(N_7,7)
    if R < 3799:
        print(x)

# %%
for N in range(10,1000):
    x=N
    N_6 = ''
    while N>0:
        N_6 = str(N%6)+N_6 
        N = N//6
    if N_6.count('0') >= 2:
        while '0' in N_6: # пока в строке есть 0 
            N_6 = N_6.replace('0','5',1) # меняем 0 на 5 
    if int(N_6[0]) % 2 == 0: # если первое число в строке четное
        N_6 = str(x%6)+N_6
    else:
        q = list(map(int,list(N_6))) # разбиваем строку на список из отдельных чисел "123"->[1,2,3]
        pr = 1
        for i in q:
            pr = pr*i # перемножаем все числа в списке 1*2*3
        pr_6 = ''
        while pr > 0: # переводим полученное произведение в 6 сс
            pr_6 = str(pr % 6)+ pr_6 
            pr = pr // 6
        N_6 = N_6+pr_6
    R = int(N_6,6)
    if R<109:
        print(x,R)

# %%
# Существуют числа, обладающие свойствами:
# Число делится на все свои цифры;
# Число, полученное из данного числа записью цифр в обратном порядке, тоже делится на все свои цифры.
# Примером такого числа является 216. Сколько существует трёхзначных чисел, без нулей в записи, обладающих этими свойствами?
q = []
for N in range(100,1000):
    if str(N).count('0') == 0:
        a = int(str(N)[0])
        b = int(str(N)[1])
        c = int(str(N)[2])
        zerk = int(str(N)[-1::-1])
        if all([N%a==0,N%b==0,N%c==0,zerk%a==0,zerk%b==0,zerk%c==0,])==1:
            q.append(N)
print(q)
print(len(q))

# %%
# На вход программы подаётся натуральное число N. Программа преобразует это число в новое число R следующим образом:
# Число N преобразуется в его двоичное представление.
# Далее эта запись обрабатывается согласно следующему алгоритму:
# Если число N делится на 4, то к двоичной записи дописываются последние две двоичные цифры.
# Если число N не делится на 4, то остаток от деления на 4 переводится в двоичную систему и дописывается в конец числа.
# Если в результате преобразования получилось число, у которого последняя цифра равна 0, эту цифру удаляют.
# Полученное число переводится в десятичную систему и выводится на экран.
q = []
for N in range(1000):
    N_bin = bin(N)[2:]
    if N%4 == 0:
        N_bin += N_bin[-2::]
    else:
        N_bin += bin(N%4)[2:]
    if N_bin[-1] == "0":
        N_bin = N_bin[0:-1]
    if int(N_bin,2) >213:
        q.append(int(N_bin,2))
print(min(q))
