# %%
# Все шестибуквенные слова, составленные из букв А, В, О, Р, Т, записаны в алфавитном порядке и
# пронумерованы начиная с 1.
# Ниже приведено начало списка.
# 1. АААААА
# 2. АААААВ
# 3. АААААО
# 4. АААААР
# 5. АААААТ
# 6. ААААВА
# …
# Под каким номером стоит слово ВОРОТА?
dict = ["А","В","О","Р","Т"]
count=0
for x1 in dict:
    for x2 in dict:
        for x3 in dict:
            for x4 in dict:
                for x5 in dict:
                    for x6 in dict:
                        if x1 == "В" and x2 == "О" and x3 == "Р" and x4 == "О" and x5 == "Т" and x6 == "А":
                            count += 1
                            q = count
                            print(x1,x2,x3,x4,x5,x6) 
                        else:
                            count +=1
print(q)
# 4821
# Out:
# В О Р О Т А
# 4821

# %%
sl = "0123456789AB"
count = 0
sh = 0
N = 0
for a in '123456789AB':
    for b in sl:
        for c in sl:
            for d in sl:
                for e in sl:
                    q = a+b+c+d+e
                    if q.count('7') == 1:
                        if q.count('9')+q.count('A')+q.count('B') <= 3:
                            N+=1
                        else:
                            break
print(N)
# Out:
# 67476

# %%
sl = "0123456789AB"
N = 0
for a in "123456789AB":
    for b in sl:
        for c in sl:
            for d in sl:
                for e in sl:
                    q = a+b+c+d+e
                    if q.count("7") == 1 and ((q.count('9') + q.count('A') + q.count('B')) <= 3):
                        N+=1
                        print(q)
print(N)
# Out:
# 10007
# 10017
# 10027
# 10037
# 10047
# 10057
# 10067
# 10070
# 10071
# 10072
# 10073
# 10074
# 10075
# 10076
# 10078
# 10079
# 1007A
# 1007B
# 10087
# 10097
# 100A7
# 100B7
# 10107
# 10117
# 10127
# 10137
# 10147
# 10157
# 10167
# 10170
# 10171
# 10172
# 10173
# 10174
# 10175
# 10176
# 10178
# 10179
# 1017A
# 1017B
# 10187
# 10197
# 101A7
# 101B7
# 10207
# 10217
# 10227
# 10237
# 10247
# 10257
# 10267
# 10270
# 10271
# 10272
# 10273
# 10274
# 10275
# 10276
# 10278
# 10279
# 1027A
# 1027B
# 10287
# 10297
# 102A7
# 102B7
# 10307
# 10317
# 10327
# 10337
# 10347
# 10357
# 10367
# 10370
# 10371
# 10372
# 10373
# 10374
# 10375
# 10376
# 10378
# 10379
# 1037A
# 1037B
# 10387
# 10397
# 103A7
# 103B7
# 10407
# 10417
# 10427
# 10437
# 10447
# 10457
# 10467
# 10470
# 10471
# 10472
# 10473
# 10474
# 10475
# 10476
# 10478
# 10479
# 1047A
# 1047B
# 10487
# 10497
# 104A7
# 104B7
# 10507
# 10517
# 10527
# 10537
# 10547
# 10557
# 10567
# 10570
# 10571
# 10572
# 10573
# 10574
# 10575
# 10576
# 10578
# ...

# %%
sl = "БЮДЖЕТНИК"
gl = 'ЮЕИ'
sgl = 'БДЖТНК'
sl = sorted(sl)
count = 0
N = 0
for a in sl:
    for b in sl:
        for c in sl:
            for d in sl:
                for e in sl:
                    for f in sl:
                        q = a+b+c+d+e+f
                        count += 1
                        if ((a in gl) and (b in sgl)and (c in gl)and (d in sgl)and (e in gl)and (f in sgl)) \
                            or ((a in sgl) and (b in gl)and (c in sgl)and (d in gl)and (e in sgl)and (f in gl)):
                            N += count
                            print(count,q,N)
                        if q=="БЮДЖЕТ":
                            exit()

# %%
c = 0
for i1 in '2468':
    for i2 in '012345678':
        for i3 in '012345678':
            for i4 in '012345678':
                for i5 in '012345678':
                    for i6 in '0145678':
                        q = i1+i2+i3+i4+i5+i6
                        if q.count('0')>=2:
                            c+=1
print(c)

# %%
c = 0
for i1 in 'АВЕНР':
    for i2 in 'АВЕНР':
        for i3 in 'АВЕНР':
            for i4 in 'АВЕНР':
                for i5 in 'АВЕНР':
                    q = i1+i2+i3+i4+i5
                    c += 1
                    if i1 == 'Р' and q.count('В') == 2 and (c%2!=0):
                        print(c,q)
